# %%
from pylab import *

figure(figsize=(10,6),dpi=60)
subplot(2,2,1)

X=np.linspace(-np.pi,np.pi,256,endpoint=True)
C,S = np.cos(X),np.sin(X)

plot(X,C,color='blue',linewidth='2.0',linestyle='-',label='cos', alpha=1.0)
plot(X,S,color='green',linewidth='1.0',linestyle='-',label='sin')
legend(loc='upper left')
xlim(-4,4)
xticks(np.linspace(-4,4,9,endpoint=True))

scatter(0,0,50,color='blue')
annotate("cosmos",xy=(0,0),fontsize=16)

subplot(2,2,2)

n = 12
X = np.arange(n)
Y1 = np.random.uniform(0.5,1.0,n)
Y2 = np.random.uniform(0.5,1.0,n)

bar(X, +Y1, facecolor='#9999ff', edgecolor='white')
bar(X, -Y2, facecolor='#ff9999', edgecolor='white')

subplot(2,2,3)

def f(x,y): return (1-x/2+x**5+y**3)*np.exp(-x**2-y**2)

n = 256
x = np.linspace(-3,3,n)
y = np.linspace(-3,3,n)
X,Y = np.meshgrid(x,y)

contourf(X, Y, f(X,Y), 8, alpha=.75, cmap='jet')

subplot(2,2,4)

n = 20
Z = np.random.uniform(0,1,n)
pie(Z), show()

show()

# %%
import numpy as np
U1 = np.random.rand(3,4)
V1 = U1 < 0.5
print(U1)
print(V1)
print(U1 * V1)
# Out:
# [[0.46763654 0.58200837 0.06295747 0.63142756]
#  [0.24579542 0.37865464 0.37806315 0.70650722]
#  [0.53464109 0.15695389 0.14458848 0.78919995]]
# [[ True False  True False]
#  [ True  True  True False]
#  [False  True  True False]]
# [[0.46763654 0.         0.06295747 0.        ]
#  [0.24579542 0.37865464 0.37806315 0.        ]
#  [0.         0.15695389 0.14458848 0.        ]]
